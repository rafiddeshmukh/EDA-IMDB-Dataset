# %% [markdown]
# <a href="https://colab.research.google.com/github/rafiddeshmukh/EDA-IMDB-Dataset/blob/main/Project_EDA_on_IMDB_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## You have been hired by a rookie movie producer to help him decide what type of movies to produce and which actors to cast. You have to back your recommendations based on thorough analysis of the data he shared with you which has the list of 3000 movies and the corresponding details.
#
# ## As a data scientist, you have to first explore the data and check its sanity.
#
# ## Further, you have to answer the following questions:
# 1. ### <b> Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.</b>
# 2. ### <b>This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)? </b>
# 3. ### <b> Find out the unique genres of movies in this dataset.</b>
# 4. ### <b> Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI? </b>
# 5. ### <b> Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor. </b>
# 6. ### <b>Top 3 directors prefer which actors the most? </b>

# %% [markdown]
# # Data Exploration

# %%
#Import package
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Almabeter/Python./dat/imdb_data.csv"
imdb_df = pd.read_csv(path)

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb_df.loc[0,'crew']
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
type(imdb_df.loc[0,'crew'])
# Out:
# str

# %%
crew_list = eval(imdb_df.loc[0,'crew'])

# %%
len(crew_list)
# Out:
# 72

# %%
eval(imdb_df.loc[0,'genres'])
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %% [markdown]
# ##Coverting the string values to proper lists and we will apply this tranformation to three columns: genres, cast and crew

# %%
def convert_string(str):
  return eval(str)

# %%
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
columns_to_keep = ['budget','genres','imdb_id','original_language',
                   'original_title','revenue','cast', 'crew','popularity']

# %%
imdb_df = imdb_df[columns_to_keep]

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   revenue            3000 non-null   int64
#  6   cast               2987 non-null   object
#  7   crew               2984 non-null   object
#  8   popularity         3000 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 211.1+ KB

# %%
imdb_non_na.shape

# %%
imdb_non_na.info()

# %%
#Apply the above funtion and drop null  to the three columns: genres
imdb_df.loc[~imdb_df['genres'].isna(),'genres'] = imdb_df.loc[~imdb_df['genres'].isna(),'genres'].apply(convert_string)

# %%
imdb_df.loc[0,'genres']
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
#Apply the above funtion and drop null value to the column: cast
imdb_df.loc[~imdb_df['cast'].isna(),'cast'] = imdb_df.loc[~imdb_df['cast'].isna(),'cast'].apply(convert_string)

# %%
imdb_df.loc[0,'cast']
# Out:
# [{'cast_id': 4,
#   'character': 'Lou',
#   'credit_id': '52fe4ee7c3a36847f82afae7',
#   'gender': 2,
#   'id': 52997,
#   'name': 'Rob Corddry',
#   'order': 0,
#   'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'},
#  {'cast_id': 5,
#   'character': 'Nick',
#   'credit_id': '52fe4ee7c3a36847f82afaeb',
#   'gender': 2,
#   'id': 64342,
#   'name': 'Craig Robinson',
#   'order': 1,
#   'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'},
#  {'cast_id': 6,
#   'character': 'Jacob',
#   'credit_id': '52fe4ee7c3a36847f82afaef',
#   'gender': 2,
#   'id': 54729,
#   'name': 'Clark Duke',
#   'order': 2,
#   'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'},
#  {'cast_id': 7,
#   'character': 'Adam Jr.',
#   'credit_id': '52fe4ee7c3a36847f82afaf3',
#   'gender': 2,
#   'id': 36801,
#   'name': 'Adam Scott',
#   'order': 3,
#   'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'},
#  {'cast_id': 8,
#   'character': 'Hot Tub Repairman',
#   'credit_id': '52fe4ee7c3a36847f82afaf7',
# ...

# %%
#Apply the above funtion and drop null value to the column: crew
imdb_df.loc[~imdb_df['crew'].isna(),'crew'] = imdb_df.loc[~imdb_df['crew'].isna(),'crew'].apply(convert_string)

# %%
imdb_df.loc[0,'crew']
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
#Creating a copy of the imdb_df
imdb_df_new = imdb_df.copy()

# %%
imdb_df_new[imdb_df['genres'].isna()]
# Out:
#        budget genres    imdb_id original_language  \
# 470   2000000    NaN  tt0349159                en
# 1622   400000    NaN  tt0261755                en
# 1814  2700000    NaN  tt0110289                it
# 1819        0    NaN  tt0352622                ru
# 2423   500000    NaN  tt0984177                en
# 2686        0    NaN  tt0833448                ru
# 2900   200000    NaN  tt1766044                en
#
#                                        original_title  revenue  \
# 470   The Book of Mormon Movie, Volume 1: The Journey  1672730
# 1622                                          Jackpot    43719
# 1814                                     Курочка Ряба  4635143
# 1819                          Небо. Самолёт. Девушка.   314195
# 2423                                        Amarkalam   500000
# 2686                                             Лифт   123182
# 2900                          Poslednyaya skazka Rity   486937
#
# ...

# %% [markdown]
# ##1.Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
imdb_df_new.describe()
# Out:
#              budget       revenue   popularity
# count  3.000000e+03  3.000000e+03  3000.000000
# mean   2.253133e+07  6.672585e+07     8.463274
# std    3.702609e+07  1.375323e+08    12.104000
# min    0.000000e+00  1.000000e+00     0.000001
# 25%    0.000000e+00  2.379808e+06     4.018053
# 50%    8.000000e+06  1.680707e+07     7.374861
# 75%    2.900000e+07  6.891920e+07    10.890983
# max    3.800000e+08  1.519558e+09   294.337037

# %%
#Replace extrreamly low values of buget and revenue with median vlue
imdb_df_new.loc[imdb_df_new['budget']< 1000,'budget'] = imdb_df_new.loc[imdb_df_new['budget']>= 1000,'budget'].median()
imdb_df_new.loc[imdb_df_new['revenue']< 1000,'revenue'] = imdb_df_new.loc[imdb_df_new['revenue']>= 1000,'revenue'].median()

# %% [markdown]
# ##Profit can be calculated as the difference between the revenue and the budget

# %%
#creat profit column
imdb_df_new['profit'] = imdb_df_new['revenue'] - imdb_df_new['budget']

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title   revenue  \
# 0                en                    Hot Tub Time Machine 2  12314651
# 1                en  The Princess Diaries 2: Royal Engagement  95149435
# 2                en                                  Whiplash  13092000
# 3                hi                                   Kahaani  16000000
# 4                ko                                      마린보이   3923970
#
#                                                 cast  \
# ...

# %%
#Calculate maximum profit
max_profit = imdb_df_new['profit'].max()

# %%
max_profit_movie_df=imdb_df_new[imdb_df_new['profit']==max_profit]

# %%
max_profit_movie_df
# Out:
#          budget                          genres    imdb_id original_language  \
# 1761  190000000  [{'id': 28, 'name': 'Action'}]  tt2820852                en
#
#      original_title     revenue  \
# 1761      Furious 7  1506249360
#
#                                                    cast  \
# 1761  [{'cast_id': 17, 'character': 'Dominic Toretto...
#
#                                                    crew  popularity  \
# 1761  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...   27.275687
#
#           profit
# 1761  1316249360

# %%
#creating the crew list : list of crew member dictionaries
crew_list = max_profit_movie_df.iloc[0]['crew']

# %%
#Get the names of producer and director
producer_list = []
director_list = []
for elem in crew_list:
  if elem['job']=='Producer':
    producer_list.append(elem['name'])
    # print(f"The producer for the movie is {elem['name']}")
  if elem['job']=='Director':
    director_list.append(elem['name'])
    # print(f"The dirctor for the movie is {elem['name']}")

# %%
producer_list,director_list
# Out:
# (['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell'],
#  ['James Wan'])

# %% [markdown]
# ##Get the actor for the highest grossing movie

# %%
#get the cast list
cast_list = max_profit_movie_df.iloc[0]['cast']

# %%
actor_list = []
for elem in cast_list:
    actor_list.append(elem['name'])

# %%
actor_list
# Out:
# ['Vin Diesel',
#  'Paul Walker',
#  'Dwayne Johnson',
#  'Michelle Rodriguez',
#  'Tyrese Gibson',
#  'Ludacris',
#  'Jordana Brewster',
#  'Djimon Hounsou',
#  'Tony Jaa',
#  'Ronda Rousey',
#  'Nathalie Emmanuel',
#  'Kurt Russell',
#  'Jason Statham',
#  'Sung Kang',
#  'Gal Gadot',
#  'Lucas Black',
#  'Elsa Pataky',
#  'Noel Gugliemi',
#  'John Brotherton',
#  'Luke Evans',
#  'Ali Fazal',
#  'Miller Kimsey',
#  'Charlie Kimsey',
#  'Eden Estrella',
#  'Gentry White',
#  'Iggy Azalea',
#  'Jon Lee Brody',
#  'Levy Tran',
#  'Anna Colwell',
#  'Viktor Hernandez',
#  'Steve Coulter',
#  'Robert Pralgo',
#  'Antwan Mills',
#  'J.J. Phillips',
#  'Jorge Ferragut',
#  'Sara Sohn',
#  'Benjamin Blankenship',
#  'D.J. Hapa',
#  'T-Pain',
#  'Brian Mahoney',
#  'Brittney Alger',
#  'Romeo Santos',
#  'Jocelin Donahue',
#  'Stephanie Langston',
#  'Jorge-Luis Pallo',
#  'Tego Calder√≥n',
#  'Nathalie Kelley',
#  'Shad Moss',
#  'Don Omar',
#  'Klement Tinaj',
#  'Caleb Walker',
# ...

# %% [markdown]
# ##2.This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
 #Calculate the ROI
 imdb_df_new['roi'] = 100 * imdb_df_new['profit']/imdb_df_new['budget']

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title   revenue  \
# 0                en                    Hot Tub Time Machine 2  12314651
# 1                en  The Princess Diaries 2: Royal Engagement  95149435
# 2                en                                  Whiplash  13092000
# 3                hi                                   Kahaani  16000000
# 4                ko                                      마린보이   3923970
#
#                                                 cast  \
# ...

# %% [markdown]
# ## We will groupby on the original language and calculate the the mean of the ROI

# %%
roi_languages_df = imdb_df_new.groupby('original_language')['roi'].mean().reset_index()

# %%
roi_languages_df
# Out:
#    original_language           roi
# 0                 ar    -91.807009
# 1                 bn    -96.739429
# 2                 cn     86.002479
# 3                 cs    -99.894267
# 4                 da     24.702661
# 5                 de    510.347257
# 6                 el   5198.013245
# 7                 en    929.987781
# 8                 es    103.433478
# 9                 fa      3.235168
# 10                fi    -30.319235
# 11                fr     51.900020
# 12                he    456.292450
# 13                hi    249.618424
# 14                hu    -95.535384
# 15                id    -41.617578
# 16                it     22.136747
# 17                ja    122.763087
# 18                ko  11277.949295
# 19                ml    370.833333
# 20                mr    193.333333
# 21                nb     18.847943
# 22                nl    -24.142008
# 23                no     24.155275
# 24                pl    395.816987
# 25                pt    -29.291459
# ...

# %%
#Finding the language with the highest average ROI
max_roi_lan = roi_languages_df[roi_languages_df['roi']==roi_languages_df['roi'].max()]['original_language']

# %%
max_roi_lan
# Out:
# 18    ko
# Name: original_language, dtype: object

# %%
print("The language with the higest average ROI is :",max_roi_lan.values)
# Out:
# The language with the higest average ROI is : ['ko']

# %% [markdown]
# ## 3.Find out the unique genres of movies in this dataset.

# %%
# Considering only those observation for which genre is not taking null values
imdb_df_no_na_genres = imdb_df_new[~imdb_df_new['genres'].isna()]

# %%
len(imdb_df_no_na_genres)
# Out:
# 2993

# %%
imdb_df_no_na_genres.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title   revenue  \
# 0                en                    Hot Tub Time Machine 2  12314651
# 1                en  The Princess Diaries 2: Royal Engagement  95149435
# 2                en                                  Whiplash  13092000
# 3                hi                                   Kahaani  16000000
# 4                ko                                      마린보이   3923970
#
#                                                 cast  \
# ...

# %%
imdb_df_no_na_genres.iloc[0]['genres']
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
for index, row in imdb_df_no_na_genres.iloc[0:5].iterrows():
  print(index)
  print(row)
# Out:
# 0
# budget                                                        14000000
# genres                                  [{'id': 35, 'name': 'Comedy'}]
# imdb_id                                                      tt2637294
# original_language                                                   en
# original_title                                  Hot Tub Time Machine 2
# revenue                                                       12314651
# cast                 [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# crew                 [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# popularity                                                    6.575393
# profit                                                        -1685349
# roi                                                         -12.038207
# Name: 0, dtype: object
# 1
# budget                                                        40000000
# genres               [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
# Creat the list of genres
genres_list = []

# Iterate over each observation
for index, row in imdb_df_no_na_genres.iterrows():
  
  #Identify the list of genres
  genre_list = row['genres']

  # we will iterate over list of dictionaries
  for elem in genre_list:
    genres_list.append(elem['name'])

# %%
set(genres_list)
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western'}

# %% [markdown]
# ## 4. Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?

# %%
# Create dataframe in which we have no null observaton for the vcolumn crew
imdb_df_no_na_crew = imdb_df_new[~imdb_df_new['crew'].isna()]

# %%
(imdb_df_no_na_crew)
# Out:
#         budget                                             genres    imdb_id  \
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4     16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
# ...        ...                                                ...        ...
# 2995  16450000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  tt0109403
# 2996  16450000  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...  tt2364975
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...  tt0116908
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  tt0343135
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...  tt1600195
#
# ...

# %%
# Creating a function whic return the list of producer and director for each movie

def get_produer_and_directors(crew_list):
  try:
    # Initialize two lists corresponding to producer and director
    producer_list = []
    director_list = []

    # Iterate over the list element
    for elem in crew_list:
      if elem['job']=='Producer':
        # Append the name of the producer to the producer list
        producer_list.append(elem['name'])

      if elem['job']=='Director':
        # Append the name of the director to the director list
        director_list.append(elem['name'])
    return producer_list,director_list
  except:
    return [],[]

# %%
get_produer_and_directors(imdb_df_no_na_crew.loc[1,'crew'])
# Out:
# (['Whitney Houston', 'Mario Iscovich', 'Debra Martin Chase'],
#  ['Garry Marshall'])

# %%
# Creating column of producer and director
imdb_df_new[['producer','director']] = imdb_df_new.apply(lambda row: get_produer_and_directors(row['crew']),axis=1,result_type="expand")

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title   revenue  \
# 0                en                    Hot Tub Time Machine 2  12314651
# 1                en  The Princess Diaries 2: Royal Engagement  95149435
# 2                en                                  Whiplash  13092000
# 3                hi                                   Kahaani  16000000
# 4                ko                                      마린보이   3923970
#
#                                                 cast  \
# ...

# %%
{
    'p1':{'movies':['m1, m2, m3'], 'avg_roi':23},
 'p2':{}

}
# Out:
# {'p1': {'movies': ['m1, m2, m3'], 'avg_roi': 23}, 'p2': {}}

# %%
producer_dict = {}
for index, row in imdb_df_new.iterrows():
  for producer in row['producer']:
    if producer not in producer_dict.keys():
      # add producer in dict
      producer_dict[producer] = [row['roi']]
    else:
      # update the movie for this producer
      value = producer_dict[producer]
      value.append(row['roi'])
      producer_dict[producer] = value

# %%
#data = {'row_1': [3, 2, 1, 0], 'row_2': ['a', 'b', 'c', 'd']}
pd.DataFrame.from_dict(producer_dict, orient='index').mean(axis=1).reset_index().rename(columns={'index':'producer', 0:'average_roi'}).sort_values('average_roi', ascending=False)
# Out:
#               producer   average_roi
# 1860        Amir Zbeda  1.288939e+06
# 2323       Robin Cowie  4.132333e+05
# 2324        Gregg Hale  4.132333e+05
# 1098         Oren Peli  2.162078e+05
# 6           Jason Blum  8.753501e+04
# ...                ...           ...
# 3223    Edward Stencel -9.998600e+01
# 3222  Tamara Hernandez -9.998600e+01
# 3221     Jessica Rains -9.998600e+01
# 3220      Honey Lauren -9.998600e+01
# 3219     Harry Ralston -9.998600e+01
#
# [3546 rows x 2 columns]

# %% [markdown]
# ## 5. Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.

# %%
imdb_df_new['new_cast'] = imdb_df_new.cast.apply(lambda x:[i['name'] for i in x] if isinstance(x,list) else [])
imdb_df_new['new_genre'] = imdb_df_new.genres.apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else [])
imdb_df_new.head(2)
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
#
#   original_language                            original_title   revenue  \
# 0                en                    Hot Tub Time Machine 2  12314651
# 1                en  The Princess Diaries 2: Royal Engagement  95149435
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
#
#                                                 crew  popularity    profit  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...    6.575393  -1685349
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...    8.248895  55149435
#
#           roi                                           producer  \
# ...

# %%
new_df = imdb_df_new.explode('new_cast')
top_actors = pd.DataFrame(new_df.new_cast.value_counts()).reset_index()
top_actors.columns = ['Actors','Number Of Movies']
top_actors.head(3)
# Out:
#               Actors  Number Of Movies
# 0     Robert De Niro                30
# 1  Samuel L. Jackson                30
# 2     Morgan Freeman                27

# %%
grouped_actors = new_df.groupby('new_cast').agg({'new_genre':'sum','profit':'mean'}).reset_index()
grouped_actors.loc[(grouped_actors.new_cast=='Robert De Niro') | (grouped_actors.new_cast=='Samuel L. Jackson') | (grouped_actors.new_cast=='Morgan Freeman')].rename({'profit':'mean_profit'},axis=1)
# Out:
#                 new_cast                                          new_genre  \
# 26518     Morgan Freeman  [Action, Drama, Science Fiction, Thriller, Dra...
# 30927     Robert De Niro  [Drama, Comedy, Drama, Comedy, Crime, Romance,...
# 32323  Samuel L. Jackson  [Action, Adventure, Crime, Thriller, Crime, Dr...
#
#         mean_profit
# 26518  7.517321e+07
# 30927  2.675375e+07
# 32323  2.243513e+08

# %% [markdown]
# ## 6. Top 3 directors prefer which actors the most?

# %%
import ast

# %%
imdb_df.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title   revenue  \
# 0                en                    Hot Tub Time Machine 2  12314651
# 1                en  The Princess Diaries 2: Royal Engagement  95149435
# 2                en                                  Whiplash  13092000
# 3                hi                                   Kahaani  16000000
# 4                ko                                      마린보이   3923970
#
#                                                 cast  \
# ...

# %%
df=pd.read_csv(path)

# %%
df['new_cast'] = df.cast.fillna('[]').apply(ast.literal_eval)
df['new_genre'] = df.genres.fillna('[]').apply(ast.literal_eval)

df['new_cast'] = df.new_cast.apply(lambda x:[i['name'] for i in x] if isinstance(x,list) else [])
df['new_genre'] = df.new_genre.apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else [])
df.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %%
new_df = df.explode('new_cast')

# %%
df.loc[df['cast'].isna(),'cast'] = df.loc[~df['cast'].isna(),'cast'].apply(convert_string)

# %%
def find_directors(li):
  #print(li)
  job_iterator = 0

  if type(li)!= float:
    li = ast.literal_eval(li)
    while True:
      if li[job_iterator]['job']!='Director':
        job_iterator+=1
      else:
        return li[job_iterator]['name']

 
 
df['director_name'] = df.apply(lambda x: find_directors(x['crew']),axis = 1)
grouped_pop = df.groupby('director_name')['popularity'].mean().sort_values(ascending = False).reset_index()
grouped_pop.head(3)
# Out:
#   director_name  popularity
# 0    Tim Miller  187.860492
# 1    James Gunn  119.311296
# 2  Edgar Wright  118.931563

# %%
pop_dir_actors_1 = list(df[df['director_name'] == grouped_pop['director_name'][0]]['new_cast'])[0]
pop_dir_actors_2 = list(df[df['director_name'] == grouped_pop['director_name'][1]]['new_cast'])[0]
pop_dir_actors_3 = list(df[df['director_name'] == grouped_pop['director_name'][2]]['new_cast'])[0]

# %%
pop_dir_actors_1
# Out:
# ['Ryan Reynolds',
#  'Morena Baccarin',
#  'Ed Skrein',
#  'T.J. Miller',
#  'Gina Carano',
#  'Leslie Uggams',
#  'Brianna Hildebrand',
#  'Jed Rees',
#  'Stefan Kapiƒçiƒá',
#  'Randal Reeder',
#  'Isaac C. Singleton Jr.',
#  'Michael Benyaer',
#  'Style Dayne',
#  'Kyle Cassie',
#  'Taylor Hickson',
#  'Ayzee',
#  'Naika Toussaint',
#  'Justyn Shippelt',
#  'Donna Yamamoto',
#  'Hugh Scott',
#  'Cindy Piper',
#  'Emily Haine',
#  'Aatash Amir',
#  'Chad Riley',
#  'Paul Belsito',
#  'Darcey Johnson',
#  'Kyle Rideout',
#  'Jason William Day',
#  'Stan Lee',
#  'Benjamin Wilkinson',
#  'Rachel Sheen',
#  'Paul Lazenby',
#  'Rob Hayter',
#  'Heather Ashley Chase',
#  'Fabiola Colmenero',
#  'Victoria De Mare',
#  'David Hardware',
#  'Matthew Hoglie',
#  'Tony Chris Kazoleas',
#  'Greg LaSalle',
#  'David Longworth',
#  'Michael Neumeyer',
#  'Sean Quan',
#  'Anthony J. Sacco',
#  'Olesia Shewchuk',
#  'Dan Zachary']

# %%
pop_dir_actors_2
# Out:
# ['Chris Pratt',
#  'Zoe Saldana',
#  'Dave Bautista',
#  'Vin Diesel',
#  'Bradley Cooper',
#  'Lee Pace',
#  'Michael Rooker',
#  'Karen Gillan',
#  'Djimon Hounsou',
#  'John C. Reilly',
#  'Glenn Close',
#  'Benicio del Toro',
#  'Wyatt Oleff',
#  'Josh Brolin',
#  'Sean Gunn',
#  'Alexis Denisof',
#  'Ophelia Lovibond',
#  'Peter Serafinowicz',
#  'Gregg Henry',
#  'Laura Haddock',
#  'Melia Kreiling',
#  'Christopher Fairbank',
#  'Mikaela Hoover',
#  'Marama Corlett',
#  'Emmett Scanlan',
#  'Alexis Rodney',
#  'Tom Proctor',
#  'Spencer Wilding',
#  'Fred',
#  'James Gunn',
#  'Stan Lee',
#  'Stephen Blackehart',
#  'Naomi Ryan',
#  'Lloyd Kaufman',
#  'Nathan Fillion',
#  'Rob Zombie',
#  'Tyler Bates',
#  'Seth Green',
#  'Krystian Godlewski',
#  'Janis Ahern',
#  'Solomon Mousley',
#  'Lindsay Morton',
#  'Robert Firth',
#  'Nick Holmes',
#  'Max Wrottesley',
#  'Nicole Alexandra Shipley',
#  'Sharif Atkins',
#  'Brendan Fehr',
#  'Ronan Summers',
#  'Tomas Arana',
# ...

# %%
pop_dir_actors_3
# Out:
# ['Simon Pegg',
#  'Nick Frost',
#  'Martin Freeman',
#  'Eddie Marsan',
#  'Paddy Considine',
#  'Rosamund Pike',
#  'Pierce Brosnan',
#  'David Bradley',
#  'Thomas Law',
#  'Zachary Bailess',
#  'Jasper Levine',
#  'James Tarpey',
#  'Luke Bromley',
#  'Sophie Evans',
#  'Samantha White',
#  'Rose Reynolds',
#  'Richard Hadfield',
#  'Flora Slorach',
#  'Francesca Reidie',
#  'Charlotte Reidie',
#  'Michael Smiley',
#  'Alex Austin',
#  'Jonathan Aris',
#  'Jenny Bede',
#  'Angie Wallis',
#  'Paul Bentall',
#  'Richard Graham',
#  'Alice Lowe',
#  'Rafe Spall',
#  'Leo Thompson',
#  'Steve Oram',
#  'Julia Deakin',
#  'Greg Townley',
#  'Sebastian Zaniesienko',
#  'Luke Scott',
#  'Tyler Dobbs',
#  'Samuel Mak',
#  'Teddy Kempner',
#  'Mark Kempner',
#  'Nick Holder',
#  'Darren Boyd',
#  'Paul Kennington',
#  'Mike Sarne',
#  'Reece Shearsmith',
#  'Nicholas Burns',
#  'Mark Heap',
#  'Kelly Franklin',
#  'Stacey Franklin',
#  'James Granstrom',
#  'Gabe Cronnelly',
# ...
